# %% [markdown]
# # PRÁCTICA 2
#
# ## Descripción
#
# La base de datos, que se va a emplear en este trabajo, contiene mediciones hechas con un teléfono móvil inteligente. En concreto, el objetivo del problema es poder realizar el reconocimiento de la actividad que el sujeto está llevando a cabo. Esta base fue construida mediante las grabaciones recogidas de 30 sujetos con edades comprendidas entre los 19 y los 48 años en el marco de un estudio clínico. A los participantes se les solicito que realizaran actividades de la vida diaria mientras llevaban en la cintura mediante un cinturón un teléfono inteligente con sensores inerciales. El objetivo es clasificar las actividades en una de las seis actividades realizadas, es decir, WALKING, WALKINGUPSTAIRS, WALKINGDOWNSTAIRS, SITTING, STANDING, LAYING. Utilizando su acelerómetro y giroscopio integrados, se capturó la aceleración lineal en 3 ejes y la velocidad angular de esos mismos 3 ejes a una frecuencia constante de 50 Hz.
#
# Las señales de los sensores (acelerómetro y giroscopio) se preprocesaron aplicando filtros de ruido y, a continuación, se muestrearon con la técnica de ventanas deslizantes de anchura fija de 2,56 segundos y con un solapamiento del 50% (128 lecturas/ventana). A partir de cada ventana, se obtuvo un vector de características calculando las variables tanto en el dominio del tiempo, como de la frecuencia. Cabe destacar que la señal de aceleración ha sido filtrada para eliminar la componente correspondiente a la gravedad y quedarse solo con el movimiento del cuerpo.
#
#
# ## Preparación de los datos:
#
# ### Carga de los datos junto con la descripción general del dominio:
#
# * Cargar la base de datos proporcionada.
# * Realizar una pequeña descripción exploratoria de los datos.

# %%
#! Primero de nada la instalación de los paquetes usados, en caso de ya tenerlos instalados
#! no ejecutar esta celda

using Pkg
# Pkg.add("DataFrames")
# Pkg.add("CSV")
# Pkg.add("Statistics")
# Pkg.add("CategoricalArrays")
# Pkg.add("MLJ")
# Pkg.add("MLJLinearModels")

# %%
# Cargar las bibliotecas necesarias
using DataFrames
using CSV
using Statistics

# 1. Cargar los datos
# Ruta del archivo CSV
ruta_archivo = "Datos/Datos_Práctica_Evaluación_1.csv"

# Leer los datos
datos = CSV.read(ruta_archivo, DataFrame)

# 2. Descripción general de los datos
println("Descripción General de los Datos\n")
println("Número de variables (columnas): ", ncol(datos))
println("Número de instancias (filas): ", nrow(datos))

# Primeras filas de los datos
println("\nPrimeras 5 filas del conjunto de datos:")
show(first(datos, 5), allcols=true)
println("\n\n")
# Calcular el número de individuos únicos
println("\nNúmero de individuos únicos: ", length(unique(datos.subject)))

# Clases de salida
clases = unique(datos.Activity)
println("\nNúmero de clases de salida: ", length(clases))
println("Clases de salida: ", clases)
# Out:
# Descripción General de los Datos
#
# Número de variables (columnas): 563
# Número de instancias (filas): 10299
#
# Primeras 5 filas del conjunto de datos:
# 5×563 DataFrame
#  Row │ subject  tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  tBodyAcc-max()-Y  tBodyAcc-max()-Z  tBodyAcc-min()-X  tBodyAcc-min()-Y  tBodyAcc-min()-Z  tBodyAcc-sma()  tBodyAcc-energy()-X  tBodyAcc-energy()-Y  tBodyAcc-energy()-Z  tBodyAcc-iqr()-X  tBodyAcc-iqr()-Y  tBodyAcc-iqr()-Z  tBodyAcc-entropy()-X  tBodyAcc-entropy()-Y  tBodyAcc-entropy()-Z  tBodyAcc-arCoeff()-X,1  tBodyAcc-arCoeff()-X,2  tBodyAcc-arCoeff()-X,3  tBodyAcc-arCoeff()-X,4  tBodyAcc-arCoeff()-Y,1  tBodyAcc-arCoeff()-Y,2  tBodyAcc-arCoeff()-Y,3  tBodyAcc-arCoeff()-Y,4  tBodyAcc-arCoeff()-Z,1  tBodyAcc-arCoeff()-Z,2  tBodyAcc-arCoeff()-Z,3  tBodyAcc-arCoeff()-Z,4  tBodyAcc-correlation()-X,Y  tBodyAcc-correlation()-X,Z  tBodyAcc-correlation()-Y,Z  tGravityAcc-mean()-X  tGravityAcc-mean()-Y  tGravityAcc-mean()-Z  tGravityAcc-std()-X  tGravityAcc-std()-Y  tGravityAcc-std()-Z  tGravityAcc-mad()-X  tGravityAcc-mad()-Y  tGravityAcc-mad()-Z  tGravityAcc-max()-X  tGravityAcc-max()-Y  tGravityAcc-max()-Z  tGravityAcc-min()-X  tGravityAcc-min()-Y  tGravityAcc-min()-Z  tGravityAcc-sma()  tGravityAcc-energy()-X  tGravityAcc-energy()-Y  tGravityAcc-energy()-Z  tGravityAcc-iqr()-X  tGravityAcc-iqr()-Y  tGravityAcc-iqr()-Z  tGravityAcc-entropy()-X  tGravityAcc-entropy()-Y  tGravityAcc-entropy()-Z  tGravityAcc-arCoeff()-X,1  tGravityAcc-arCoeff()-X,2  tGravityAcc-arCoeff()-X,3  tGravityAcc-arCoeff()-X,4  tGravityAcc-arCoeff()-Y,1  tGravityAcc-arCoeff()-Y,2  tGravityAcc-arCoeff()-Y,3  tGravityAcc-arCoeff()-Y,4  tGravityAcc-arCoeff()-Z,1  tGravityAcc-arCoeff()-Z,2  tGravityAcc-arCoeff()-Z,3  tGravityAcc-arCoeff()-Z,4  tGravityAcc-correlation()-X,Y  tGravityAcc-correlation()-X,Z  tGravityAcc-correlation()-Y,Z  tBodyAccJerk-mean()-X  tBodyAccJerk-mean()-Y  tBodyAccJerk-mean()-Z  tBodyAccJerk-std()-X  tBodyAccJerk-std()-Y  tBodyAccJerk-std()-Z  tBodyAccJerk-mad()-X  tBodyAccJerk-mad()-Y  tBodyAccJerk-mad()-Z  tBodyAccJerk-max()-X  tBodyAccJerk-max()-Y  tBodyAccJerk-max()-Z  tBodyAccJerk-min()-X  tBodyAccJerk-min()-Y  tBodyAccJerk-min()-Z  tBodyAccJerk-sma()  tBodyAccJerk-energy()-X  tBodyAccJerk-energy()-Y  tBodyAccJerk-energy()-Z  tBodyAccJerk-iqr()-X  tBodyAccJerk-iqr()-Y  tBodyAccJerk-iqr()-Z  tBodyAccJerk-entropy()-X  tBodyAccJerk-entropy()-Y  tBodyAccJerk-entropy()-Z  tBodyAccJerk-arCoeff()-X,1  tBodyAccJerk-arCoeff()-X,2  tBodyAccJerk-arCoeff()-X,3  tBodyAccJerk-arCoeff()-X,4  tBodyAccJerk-arCoeff()-Y,1  tBodyAccJerk-arCoeff()-Y,2  tBodyAccJerk-arCoeff()-Y,3  tBodyAccJerk-arCoeff()-Y,4  tBodyAccJerk-arCoeff()-Z,1  tBodyAccJerk-arCoeff()-Z,2  tBodyAccJerk-arCoeff()-Z,3  tBodyAccJerk-arCoeff()-Z,4  tBodyAccJerk-correlation()-X,Y  tBodyAccJerk-correlation()-X,Z  tBodyAccJerk-correlation()-Y,Z  tBodyGyro-mean()-X  tBodyGyro-mean()-Y  tBodyGyro-mean()-Z  tBodyGyro-std()-X  tBodyGyro-std()-Y  tBodyGyro-std()-Z  tBodyGyro-mad()-X  tBodyGyro-mad()-Y  tBodyGyro-mad()-Z  tBodyGyro-max()-X  tBodyGyro-max()-Y  tBodyGyro-max()-Z  tBodyGyro-min()-X  tBodyGyro-min()-Y  tBodyGyro-min()-Z  tBodyGyro-sma()  tBodyGyro-energy()-X  tBodyGyro-energy()-Y  tBodyGyro-energy()-Z  tBodyGyro-iqr()-X  tBodyGyro-iqr()-Y  tBodyGyro-iqr()-Z  tBodyGyro-entropy()-X  tBodyGyro-entropy()-Y  tBodyGyro-entropy()-Z  tBodyGyro-arCoeff()-X,1  tBodyGyro-arCoeff()-X,2  tBodyGyro-arCoeff()-X,3  tBodyGyro-arCoeff()-X,4  tBodyGyro-arCoeff()-Y,1  tBodyGyro-arCoeff()-Y,2  tBodyGyro-arCoeff()-Y,3  tBodyGyro-arCoeff()-Y,4  tBodyGyro-arCoeff()-Z,1  tBodyGyro-arCoeff()-Z,2  tBodyGyro-arCoeff()-Z,3  tBodyGyro-arCoeff()-Z,4  tBodyGyro-correlation()-X,Y  tBodyGyro-correlation()-X,Z  tBodyGyro-correlation()-Y,Z  tBodyGyroJerk-mean()-X  tBodyGyroJerk-mean()-Y  tBodyGyroJerk-mean()-Z  tBodyGyroJerk-std()-X  tBodyGyroJerk-std()-Y  tBodyGyroJerk-std()-Z  tBodyGyroJerk-mad()-X  tBodyGyroJerk-mad()-Y  tBodyGyroJerk-mad()-Z  tBodyGyroJerk-max()-X  tBodyGyroJerk-max()-Y  tBodyGyroJerk-max()-Z  tBodyGyro ...
#      │ Int64    Float64            Float64            Float64            Float64?          Float64           Float64?          Float64?          Float64?          Float64?          Float64?          Float64           Float64?          Float64           Float64           Float64           Float64?        Float64              Float64              Float64              Float64?          Float64?          Float64           Float64               Float64               Float64               Float64                 Float64                 Float64                 Float64                 Float64                 Float64                 Float64                 Float64                 Float64                 Float64                 Float64                 Float64                 Float64                     Float64                     Float64                     Float64               Float64               Float64               Float64              Float64              Float64              Float64              Float64              Float64              Float64              Float64              Float64              Float64              Float64              Float64              Float64            Float64                 Float64                 Float64                 Float64              Float64              Float64              Float64                  Float64                  Float64                  Float64                    Float64                    Float64                    Float64                    Float64                    Float64                    Float64                    Float64                    Float64                    Float64                    Float64                    Float64                    Float64                        Float64                        Float64                        Float64                Float64                Float64                Float64?              Float64               Float64               Float64?              Float64?              Float64?              Float64?              Float64               Float64               Float64               Float64               Float64               Float64?            Float64?                 Float64?                 Float64                  Float64               Float64?              Float64?              Float64?                  Float64?                  Float64?                  Float64                     Float64                     Float64                     Float64                     Float64                     Float64                     Float64                     Float64                     Float64                     Float64                     Float64                     Float64                     Float64                         Float64                         Float64                         Float64             Float64             Float64             Float64            Float64            Float64            Float64            Float64?           Float64            Float64            Float64            Float64            Float64            Float64            Float64            Float64?         Float64               Float64               Float64               Float64            Float64?           Float64            Float64                Float64                Float64                Float64                  Float64                  Float64                  Float64                  Float64                  Float64                  Float64                  Float64                  Float64                  Float64                  Float64                  Float64                  Float64                      Float64                      Float64                      Float64                 Float64                 Float64                 Float64?               Float64                Float64?               Float64?               Float64                Float64?               Float64                Float64                Float64                Float64   ...
# ─────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── ...
#    1 │       1           0.288585         -0.0202942          -0.132905         -0.995279         -0.983111         -0.913526         -0.995112         -0.983185         -0.923527         -0.934724         -0.567378         -0.744413          0.852947          0.685845          0.814263       -0.965523            -0.999945            -0.999863            -0.994612         -0.994231         -0.987614         -0.94322              -0.407747             -0.679338             -0.602122               0.929294                -0.853011               0.35991                -0.0585264               0.256892               -0.224848                0.264106              -0.0952456                 0.278851               -0.465085                0.491936              -0.190884                     0.376314                  0.435129                     0.66079                0.963396             -0.14084               0.115375            -0.98525             -0.981708            -0.877625            -0.985001            -0.984416            -0.894677             0.892055           -0.161265              0.12466              0.977436            -0.123213            0.0564827         -0.375426                 0.899469               -0.970905               -0.97551             -0.984325            -0.988849            -0.917743                     -1.0                -1.0                      0.113806                  -0.590425                   0.591146                  -0.591773                   0.592469                  -0.745449                   0.720862                 -0.712372                    0.7113                    -0.995112                   0.995675                  -0.995668                   0.991653                       0.570222                       0.439027                       0.986913              0.0779963             0.0050008             -0.0678308              -0.993519             -0.98836              -0.993575             -0.994488             -0.986207             -0.992818             -0.98518              -0.991994             -0.993119              0.989835              0.991957              0.990519           -0.993522                -0.999935                -0.99982                 -0.999878             -0.994364             -0.986025             -0.989234                 -0.819949                 -0.793046                 -0.888853                   1.0                         -0.220747                   0.636831                    0.387644                    0.241401                   -0.0522528                    0.264177                   0.373439                     0.341778                  -0.569791                    0.265399                   -0.477875                       -0.3853                          0.0336439                      -0.126511          -0.00610085          -0.0313648           0.107725           -0.98531           -0.976623          -0.992205          -0.984586          -0.976353          -0.992362          -0.867044          -0.933786          -0.747566           0.847308           0.914895           0.830841        -0.967184             -0.999578             -0.999354             -0.999763          -0.983438          -0.978614          -0.992966              0.0826317               0.202268              -0.168757              0.0963232                  -0.274985                 0.498644              -0.220317                  1.0                    -0.972971                  0.316655                 0.375726                  0.723399                -0.771112                0.690213                -0.331831                     0.709584                      0.134873                    0.301099               -0.0991674              -0.0555174              -0.0619858              -0.992111              -0.992519              -0.992055              -0.992165              -0.994942              -0.992619              -0.990156              -0.986743              -0.992042            ...
#    2 │       1           0.274262         -0.0122647          -0.109494         -0.993865         -0.977421         -0.989336         -0.995502         -0.975182         -0.989586         -0.938716         -0.561801         -0.812655          0.840255          0.689579          0.843532       -0.98881             -0.999953            -0.999774            -0.999801         -0.99789          -0.974333         -0.989654             -0.669412             -0.38136              -0.579228              -0.0274792                0.138216              -0.102128                0.157766               -0.0414715              -0.042687                0.190033              -0.0775771                 0.298807               -0.13848                 0.217925              -0.0887187                   -0.185076                  0.00217639                  -0.235451               0.917237              0.119316              0.238581            -0.99553             -0.984233            -0.996702            -0.995318            -0.983378            -0.997055             0.843624            0.0928337             0.229075             0.936834             0.141056            0.240431          -0.0952336                0.779481               -0.963567               -0.892671            -0.994677            -0.98145             -0.997918                     -1.0                -0.560427                -0.775959                  -0.281789                   0.292801                  -0.30372                    0.314654                  -0.569477                   0.53075                  -0.519349                    0.520359                  -0.404778                   0.430632                  -0.456231                   0.478964                      -0.996856                       0.63088                       -0.669298              0.0704911             0.0127462              0.026885               -0.991798             -0.99161              -0.991944             -0.992585             -0.99168              -0.992442             -0.994611             -0.99067              -0.983417              0.986748              0.992092              0.995748           -0.994266                -0.999911                -0.999884                -0.999848             -0.993165             -0.991686             -0.992248                 -0.74495                  -0.84896                  -0.761514                  -0.0155018                    0.275806                   0.13966                     0.0813298                  -0.0292079                  -0.0014241                    0.129016                   0.362534                     0.181277                  -0.0706914                   0.135828                    0.149467                        0.0859675                       0.239069                       -0.0489284         -0.0300561           -0.0901088           0.0850331          -0.987364          -0.966599          -0.974426          -0.993125          -0.983659          -0.981409          -0.885939          -0.95302           -0.750639           0.823699           0.856668           0.776098        -0.986777             -0.999902             -0.999324             -0.999594          -0.998332          -0.995086          -0.986573             -0.700089               -0.606151              -0.364                 0.000704167                -0.167165                 0.138978               0.399202                 -0.360884                0.233229                 -0.310537                 0.587315                 -0.250463                 0.123383               -0.0464162                0.273143                     0.921745                      0.771348                    0.812544               -0.113281               -0.0898321              -0.0854861              -0.996012              -0.990604              -0.990742              -0.99656               -0.993237              -0.9938                -0.998368              -0.997679              -0.993222            ...
#    3 │       1           0.277258         -0.0142493          -0.112205         -0.997016         -0.97768          -0.99714          -0.997566         -0.974858         -0.99673          -0.941152         -0.561801         -0.826332          0.849422          0.68921           0.843532       -0.992846            -0.999983            -0.999805            -0.99994          -0.997928         -0.974055         -0.99611              -0.702793             -0.420824             -0.72366                0.424252                -0.226189               0.0697567               0.171673                0.108834               -0.135147                0.118715               0.00839199                0.451387               -0.240792                0.192114              -0.0245009                   -0.448386                 -0.0342687                    0.0642886              0.917675              0.11742               0.239912            -0.997635            -0.99456             -0.993395            -0.997545            -0.994379            -0.993237             0.843624            0.0882766             0.230568             0.937953             0.141056            0.240922          -0.0959841                0.7806                 -0.964581               -0.891439            -0.997146            -0.994002            -0.992493                     -1.0                -0.714487                -0.730019                  -0.262296                   0.265919                  -0.269118                   0.272005                  -0.723112                   0.700825                 -0.696197                    0.699423                  -0.299878                   0.352908                  -0.406575                   0.458258                      -0.944588                      -0.844506                       0.714742              0.0685888             0.0224247             -0.0115362              -0.994997             -0.997581             -0.996745             -0.99493              -0.996816             -0.995784             -0.995119             -0.998292             -0.994031              0.992937              0.999632              0.998781           -0.997799                -0.999953                -0.999973                -0.999946             -0.993917             -0.995266             -0.995073                 -0.797465                 -0.895253                 -0.87827                    0.373542                     0.161766                   0.202921                    0.313405                    0.162067                   -0.0675747                    0.21293                    0.0676831                    0.368428                  -0.0851201                   0.195887                   -0.0230457                      -0.120541                        0.116861                       -0.016366          -0.0281474           -0.0731287           0.0822131          -0.998412          -0.995605          -0.990444          -0.998484          -0.99536           -0.99065           -0.885939          -0.953686          -0.752819           0.845203           0.914021           0.82476         -0.995416             -0.999997             -0.999979             -0.999912          -0.998519          -0.995093          -0.99152              -0.766498               -0.488045              -0.575314              0.361647                   -0.229765                 0.372751              -0.00433723                0.0830737              -0.0608243                 0.11848                  0.0120939                 0.332082                -0.283162                0.240052                -0.165312                    -0.371077                      0.364939                   -0.362253               -0.0976364              -0.041078               -0.0507782              -0.997753              -0.997297              -0.995378              -0.997458              -0.997233              -0.995262              -0.998368              -0.998168              -0.993222            ...
#    4 │       1           0.277782         -0.0158736          -0.110504         -0.996929         -0.981925         -0.996716         -0.997586         -0.979271         -0.995642         -0.941152         -0.569591         -0.822759          0.84909           0.68921           0.848162       -0.994068            -0.999983            -0.999866            -0.999948         -0.998172         -0.978061         -0.990646             -0.710136             -0.530799             -0.67857                0.356509                -0.199752               0.0743668               0.260706                0.0723396              -0.0633647               0.0885107             -0.0256412                 0.647391               -0.449525                0.246442               0.173655                    -0.403676                  0.0639235                    0.155749               0.917706              0.116586              0.240917            -0.996927            -0.989789            -0.99716             -0.99699             -0.989517            -0.997162             0.844358            0.0882766             0.230694             0.937953             0.138652            0.242542          -0.0955035                0.780679               -0.96501                -0.890507            -0.997029            -0.988869            -0.997117                     -1.0                -0.715545                -1.0                       -0.336933                   0.344743                  -0.352545                   0.360463                  -0.41651                    0.360944                 -0.342202                    0.34032                   -0.452204                   0.466084                  -0.47955                    0.490001                      -0.948158                      -0.5771                         0.298991              0.0753559             0.00618075            -0.0245324              -0.995132             -0.994705             -0.997914             -0.994909             -0.993173             -0.996787             -0.995119             -0.998888             -0.99726               0.992937              0.994883              0.998968           -0.997136                -0.999955                -0.999935                -0.999966             -0.994718             -0.992495             -0.996193                 -0.807351                 -0.84773                  -0.922161                   0.270342                     0.132705                   0.113662                    0.379814                    0.10378                     0.0682082                    0.171099                   0.245954                     0.398275                  -0.262804                    0.0199659                   0.0289762                      -0.104525                        0.350764                        0.0638703         -0.0281136           -0.0750255           0.090116           -0.998489          -0.994929          -0.990545          -0.998526          -0.994681          -0.990542          -0.885956          -0.953686          -0.752819           0.845203           0.913791           0.82519         -0.99533              -0.999997             -0.999974             -0.999914          -0.998669          -0.994234          -0.991457             -0.749266               -0.521195              -0.414761              0.331347                   -0.226361                 0.53246               -0.38394                   0.10756                -0.0809061                 0.12892                 -0.0402073                 0.339778                -0.319637                0.256864                -0.100904                    -0.36685                       0.428042                   -0.193392               -0.0980328              -0.037871               -0.0553277              -0.997747              -0.99712               -0.995975              -0.997747              -0.997297              -0.995505              -0.997771              -0.997502              -0.994436            ...
#    5 │       1           0.275549         -0.0141152          -0.108999         -0.997599         -0.985257         -0.995653         -0.997931         -0.982909         -0.995529         -0.94412          -0.569591         -0.822759          0.848602          0.694178          0.846916       -0.994718            -0.999986            -0.999886            -0.999936         -0.997594         -0.982033         -0.995476             -0.796051             -0.500925             -0.648278               0.269291                -0.171246               0.0408714               0.185328                0.40563                -0.329121                0.302179              -0.22396                   0.566623               -0.413461                0.307308              -0.046515                    -0.439308                 -0.183613                     0.278686               0.918249              0.115041              0.240877            -0.997355            -0.993942            -0.997252            -0.997303            -0.993875            -0.997254             0.844375            0.0869382             0.230694             0.938241             0.138652            0.242667          -0.0987601                0.782069               -0.965813               -0.890544            -0.997111            -0.993642            -0.997466                     -1.0                -0.966824                -1.0                       -0.366541                   0.368899                  -0.371153                   0.373438                  -0.200492                   0.122817                 -0.0955698                   0.091521                  -0.419078                   0.430883                  -0.441962                   0.449781                      -0.966318                      -0.922639                       0.869383              0.0788183             0.0121931              0.00204078             -0.997135             -0.992302             -0.998425             -0.997026             -0.990934             -0.997708             -0.997952             -0.994319             -0.997595              0.99514               0.994883              0.997134           -0.997768                -0.999976                -0.999896                -0.999975             -0.995483             -0.989568             -0.997864                 -0.862673                 -0.806636                 -0.912522                   0.18621                      0.134974                   0.0604868                   0.301583                    0.479713                   -0.0693943                    0.483225                   0.328175                     0.478596                  -0.224161                    0.189651                    0.27393                         0.0559625                       0.310719                        0.131998          -0.0271514           -0.076315            0.0892271          -0.99893           -0.995932          -0.992753          -0.998824          -0.995703          -0.992956          -0.885956          -0.955951          -0.753292           0.847086           0.913791           0.829453        -0.996755             -0.999998             -0.999981             -0.999943          -0.997971          -0.99506           -0.994479             -0.676549               -0.600903              -0.487808              0.332328                   -0.209871                 0.56474               -0.323126                  0.0495554              -0.00732458                0.0719384                0.110152                  0.334386                -0.355524                0.344128                -0.0854144                   -0.0768427                     0.173998                    0.0717277              -0.0983735              -0.0397843              -0.0545847              -0.998259              -0.99696               -0.996641              -0.998514              -0.996891              -0.996871              -0.997771              -0.997502              -0.994436            ...
#
#
#
# Número de individuos únicos: 30
#
# Número de clases de salida: 6
# Clases de salida: String31["STANDING", "SITTING", "LAYING", "WALKING", "WALKING_UPSTAIRS", "WALKING_DOWNSTAIRS"]

# %% [markdown]
# ### Análisis de valores nulos
# * Calcular el porcentaje de **valores nulos por variable**.
# * Determinar el **porcentaje total** de **valores nulos** en el conjunto de datos.

# %%
# Análisis de valores nulos

# Función para calcular el porcentaje de valores nulos por columna
function porcentaje_nulos_por_columna(df::DataFrame)
    return [sum(ismissing.(df[!, col])) / nrow(df) * 100 for col in names(df)]
end

# 1. Calcular el porcentaje de valores nulos por variable
println("\nPorcentaje de valores nulos por variable:")
porcentajes_nulos = porcentaje_nulos_por_columna(datos)

# Mostrar los porcentajes en formato tabular
for (columna, porcentaje) in zip(names(datos), porcentajes_nulos)
    println("$(columna): $(round(porcentaje, digits=2))%")
end

# 2. Calcular el porcentaje total de valores nulos en todo el conjunto de datos
total_nulos = sum(sum(ismissing.(datos[!, col])) for col in names(datos))
porcentaje_total_nulos = total_nulos / (nrow(datos) * ncol(datos)) * 100

println("\nPorcentaje total de valores nulos en el conjunto de datos: ", round(porcentaje_total_nulos, digits=2), "%")
# Out:
# Porcentaje de valores nulos por variable:
# subject: 0.0%
# tBodyAcc-mean()-X: 0.0%
# tBodyAcc-mean()-Y: 0.0%
# tBodyAcc-mean()-Z: 0.0%
# tBodyAcc-std()-X: 0.02%
# tBodyAcc-std()-Y: 0.0%
# tBodyAcc-std()-Z: 0.02%
# tBodyAcc-mad()-X: 0.02%
# tBodyAcc-mad()-Y: 0.03%
# tBodyAcc-mad()-Z: 0.03%
# tBodyAcc-max()-X: 0.02%
# tBodyAcc-max()-Y: 0.0%
# tBodyAcc-max()-Z: 0.01%
# tBodyAcc-min()-X: 0.0%
# tBodyAcc-min()-Y: 0.0%
# tBodyAcc-min()-Z: 0.0%
# tBodyAcc-sma(): 0.01%
# tBodyAcc-energy()-X: 0.0%
# tBodyAcc-energy()-Y: 0.0%
# tBodyAcc-energy()-Z: 0.0%
# tBodyAcc-iqr()-X: 0.03%
# tBodyAcc-iqr()-Y: 0.01%
# tBodyAcc-iqr()-Z: 0.0%
# tBodyAcc-entropy()-X: 0.0%
# tBodyAcc-entropy()-Y: 0.0%
# tBodyAcc-entropy()-Z: 0.0%
# tBodyAcc-arCoeff()-X,1: 0.0%
# tBodyAcc-arCoeff()-X,2: 0.0%
# tBodyAcc-arCoeff()-X,3: 0.0%
# tBodyAcc-arCoeff()-X,4: 0.0%
# tBodyAcc-arCoeff()-Y,1: 0.0%
# tBodyAcc-arCoeff()-Y,2: 0.0%
# tBodyAcc-arCoeff()-Y,3: 0.0%
# tBodyAcc-arCoeff()-Y,4: 0.0%
# tBodyAcc-arCoeff()-Z,1: 0.0%
# tBodyAcc-arCoeff()-Z,2: 0.0%
# tBodyAcc-arCoeff()-Z,3: 0.0%
# tBodyAcc-arCoeff()-Z,4: 0.0%
# tBodyAcc-correlation()-X,Y: 0.0%
# tBodyAcc-correlation()-X,Z: 0.0%
# tBodyAcc-correlation()-Y,Z: 0.0%
# tGravityAcc-mean()-X: 0.0%
# tGravityAcc-mean()-Y: 0.0%
# tGravityAcc-mean()-Z: 0.0%
# tGravityAcc-std()-X: 0.0%
# tGravityAcc-std()-Y: 0.0%
# tGravityAcc-std()-Z: 0.0%
# tGravityAcc-mad()-X: 0.0%
# tGravityAcc-mad()-Y: 0.0%
# tGravityAcc-mad()-Z: 0.0%
# tGravityAcc-max()-X: 0.0%
# tGravityAcc-max()-Y: 0.0%
# tGravityAcc-max()-Z: 0.0%
# tGravityAcc-min()-X: 0.0%
# tGravityAcc-min()-Y: 0.0%
# tGravityAcc-min()-Z: 0.0%
# tGravityAcc-sma(): 0.0%
# tGravityAcc-energy()-X: 0.0%
# tGravityAcc-energy()-Y: 0.0%
# tGravityAcc-energy()-Z: 0.0%
# tGravityAcc-iqr()-X: 0.0%
# tGravityAcc-iqr()-Y: 0.0%
# tGravityAcc-iqr()-Z: 0.0%
# tGravityAcc-entropy()-X: 0.0%
# tGravityAcc-entropy()-Y: 0.0%
# tGravityAcc-entropy()-Z: 0.0%
# tGravityAcc-arCoeff()-X,1: 0.0%
# tGravityAcc-arCoeff()-X,2: 0.0%
# tGravityAcc-arCoeff()-X,3: 0.0%
# tGravityAcc-arCoeff()-X,4: 0.0%
# tGravityAcc-arCoeff()-Y,1: 0.0%
# tGravityAcc-arCoeff()-Y,2: 0.0%
# tGravityAcc-arCoeff()-Y,3: 0.0%
# tGravityAcc-arCoeff()-Y,4: 0.0%
# tGravityAcc-arCoeff()-Z,1: 0.0%
# tGravityAcc-arCoeff()-Z,2: 0.0%
# tGravityAcc-arCoeff()-Z,3: 0.0%
# tGravityAcc-arCoeff()-Z,4: 0.0%
# tGravityAcc-correlation()-X,Y: 0.0%
# tGravityAcc-correlation()-X,Z: 0.0%
# tGravityAcc-correlation()-Y,Z: 0.0%
# tBodyAccJerk-mean()-X: 0.0%
# tBodyAccJerk-mean()-Y: 0.0%
# tBodyAccJerk-mean()-Z: 0.0%
# tBodyAccJerk-std()-X: 0.01%
# tBodyAccJerk-std()-Y: 0.0%
# tBodyAccJerk-std()-Z: 0.0%
# tBodyAccJerk-mad()-X: 0.04%
# tBodyAccJerk-mad()-Y: 0.04%
# tBodyAccJerk-mad()-Z: 0.02%
# tBodyAccJerk-max()-X: 0.01%
# tBodyAccJerk-max()-Y: 0.0%
# tBodyAccJerk-max()-Z: 0.0%
# tBodyAccJerk-min()-X: 0.0%
# tBodyAccJerk-min()-Y: 0.0%
# tBodyAccJerk-min()-Z: 0.0%
# tBodyAccJerk-sma(): 0.03%
# tBodyAccJerk-energy()-X: 0.01%
# tBodyAccJerk-energy()-Y: 0.01%
# tBodyAccJerk-energy()-Z: 0.0%
# tBodyAccJerk-iqr()-X: 0.0%
# tBodyAccJerk-iqr()-Y: 0.03%
# tBodyAccJerk-iqr()-Z: 0.02%
# tBodyAccJerk-entropy()-X: 0.02%
# tBodyAccJerk-entropy()-Y: 0.01%
# tBodyAccJerk-entropy()-Z: 0.01%
# tBodyAccJerk-arCoeff()-X,1: 0.0%
# tBodyAccJerk-arCoeff()-X,2: 0.0%
# tBodyAccJerk-arCoeff()-X,3: 0.0%
# tBodyAccJerk-arCoeff()-X,4: 0.0%
# tBodyAccJerk-arCoeff()-Y,1: 0.0%
# tBodyAccJerk-arCoeff()-Y,2: 0.0%
# tBodyAccJerk-arCoeff()-Y,3: 0.0%
# tBodyAccJerk-arCoeff()-Y,4: 0.0%
# tBodyAccJerk-arCoeff()-Z,1: 0.0%
# tBodyAccJerk-arCoeff()-Z,2: 0.0%
# tBodyAccJerk-arCoeff()-Z,3: 0.0%
# tBodyAccJerk-arCoeff()-Z,4: 0.0%
# tBodyAccJerk-correlation()-X,Y: 0.0%
# tBodyAccJerk-correlation()-X,Z: 0.0%
# tBodyAccJerk-correlation()-Y,Z: 0.0%
# tBodyGyro-mean()-X: 0.0%
# tBodyGyro-mean()-Y: 0.0%
# tBodyGyro-mean()-Z: 0.0%
# tBodyGyro-std()-X: 0.0%
# tBodyGyro-std()-Y: 0.0%
# tBodyGyro-std()-Z: 0.0%
# tBodyGyro-mad()-X: 0.0%
# tBodyGyro-mad()-Y: 0.02%
# tBodyGyro-mad()-Z: 0.0%
# tBodyGyro-max()-X: 0.0%
# tBodyGyro-max()-Y: 0.0%
# tBodyGyro-max()-Z: 0.0%
# tBodyGyro-min()-X: 0.0%
# tBodyGyro-min()-Y: 0.0%
# tBodyGyro-min()-Z: 0.0%
# tBodyGyro-sma(): 0.01%
# tBodyGyro-energy()-X: 0.0%
# tBodyGyro-energy()-Y: 0.0%
# tBodyGyro-energy()-Z: 0.0%
# tBodyGyro-iqr()-X: 0.0%
# tBodyGyro-iqr()-Y: 0.03%
# tBodyGyro-iqr()-Z: 0.0%
# tBodyGyro-entropy()-X: 0.0%
# tBodyGyro-entropy()-Y: 0.0%
# tBodyGyro-entropy()-Z: 0.0%
# tBodyGyro-arCoeff()-X,1: 0.0%
# tBodyGyro-arCoeff()-X,2: 0.0%
# tBodyGyro-arCoeff()-X,3: 0.0%
# tBodyGyro-arCoeff()-X,4: 0.0%
# tBodyGyro-arCoeff()-Y,1: 0.0%
# tBodyGyro-arCoeff()-Y,2: 0.0%
# tBodyGyro-arCoeff()-Y,3: 0.0%
# tBodyGyro-arCoeff()-Y,4: 0.0%
# tBodyGyro-arCoeff()-Z,1: 0.0%
# tBodyGyro-arCoeff()-Z,2: 0.0%
# tBodyGyro-arCoeff()-Z,3: 0.0%
# tBodyGyro-arCoeff()-Z,4: 0.0%
# tBodyGyro-correlation()-X,Y: 0.0%
# tBodyGyro-correlation()-X,Z: 0.0%
# tBodyGyro-correlation()-Y,Z: 0.0%
# tBodyGyroJerk-mean()-X: 0.0%
# tBodyGyroJerk-mean()-Y: 0.0%
# tBodyGyroJerk-mean()-Z: 0.0%
# tBodyGyroJerk-std()-X: 0.01%
# tBodyGyroJerk-std()-Y: 0.0%
# tBodyGyroJerk-std()-Z: 0.01%
# tBodyGyroJerk-mad()-X: 0.02%
# tBodyGyroJerk-mad()-Y: 0.0%
# tBodyGyroJerk-mad()-Z: 0.01%
# tBodyGyroJerk-max()-X: 0.0%
# tBodyGyroJerk-max()-Y: 0.0%
# tBodyGyroJerk-max()-Z: 0.0%
# tBodyGyroJerk-min()-X: 0.0%
# tBodyGyroJerk-min()-Y: 0.0%
# tBodyGyroJerk-min()-Z: 0.0%
# tBodyGyroJerk-sma(): 0.01%
# tBodyGyroJerk-energy()-X: 0.0%
# tBodyGyroJerk-energy()-Y: 0.0%
# tBodyGyroJerk-energy()-Z: 0.0%
# tBodyGyroJerk-iqr()-X: 0.03%
# tBodyGyroJerk-iqr()-Y: 0.0%
# tBodyGyroJerk-iqr()-Z: 0.03%
# tBodyGyroJerk-entropy()-X: 0.02%
# tBodyGyroJerk-entropy()-Y: 0.03%
# tBodyGyroJerk-entropy()-Z: 0.0%
# tBodyGyroJerk-arCoeff()-X,1: 0.0%
# tBodyGyroJerk-arCoeff()-X,2: 0.0%
# tBodyGyroJerk-arCoeff()-X,3: 0.0%
# tBodyGyroJerk-arCoeff()-X,4: 0.0%
# tBodyGyroJerk-arCoeff()-Y,1: 0.0%
# tBodyGyroJerk-arCoeff()-Y,2: 0.0%
# tBodyGyroJerk-arCoeff()-Y,3: 0.0%
# tBodyGyroJerk-arCoeff()-Y,4: 0.0%
# tBodyGyroJerk-arCoeff()-Z,1: 0.0%
# tBodyGyroJerk-arCoeff()-Z,2: 0.0%
# tBodyGyroJerk-arCoeff()-Z,3: 0.0%
# tBodyGyroJerk-arCoeff()-Z,4: 0.0%
# tBodyGyroJerk-correlation()-X,Y: 0.0%
# tBodyGyroJerk-correlation()-X,Z: 0.0%
# tBodyGyroJerk-correlation()-Y,Z: 0.0%
# tBodyAccMag-mean(): 0.0%
# tBodyAccMag-std(): 0.04%
# tBodyAccMag-mad(): 0.02%
# tBodyAccMag-max(): 0.01%
# tBodyAccMag-min(): 0.0%
# tBodyAccMag-sma(): 0.03%
# tBodyAccMag-energy(): 0.02%
# tBodyAccMag-iqr(): 0.01%
# tBodyAccMag-entropy(): 0.04%
# tBodyAccMag-arCoeff()1: 0.0%
# tBodyAccMag-arCoeff()2: 0.0%
# tBodyAccMag-arCoeff()3: 0.0%
# tBodyAccMag-arCoeff()4: 0.0%
# tGravityAccMag-mean(): 0.02%
# tGravityAccMag-std(): 0.01%
# tGravityAccMag-mad(): 0.01%
# tGravityAccMag-max(): 0.02%
# tGravityAccMag-min(): 0.0%
# tGravityAccMag-sma(): 0.03%
# tGravityAccMag-energy(): 0.01%
# tGravityAccMag-iqr(): 0.01%
# tGravityAccMag-entropy(): 0.01%
# tGravityAccMag-arCoeff()1: 0.0%
# tGravityAccMag-arCoeff()2: 0.0%
# tGravityAccMag-arCoeff()3: 0.0%
# tGravityAccMag-arCoeff()4: 0.0%
# tBodyAccJerkMag-mean(): 0.04%
# tBodyAccJerkMag-std(): 0.0%
# tBodyAccJerkMag-mad(): 0.02%
# tBodyAccJerkMag-max(): 0.01%
# tBodyAccJerkMag-min(): 0.02%
# tBodyAccJerkMag-sma(): 0.02%
# tBodyAccJerkMag-energy(): 0.02%
# tBodyAccJerkMag-iqr(): 0.02%
# tBodyAccJerkMag-entropy(): 0.02%
# tBodyAccJerkMag-arCoeff()1: 0.0%
# tBodyAccJerkMag-arCoeff()2: 0.0%
# tBodyAccJerkMag-arCoeff()3: 0.0%
# tBodyAccJerkMag-arCoeff()4: 0.0%
# tBodyGyroMag-mean(): 0.0%
# tBodyGyroMag-std(): 0.02%
# tBodyGyroMag-mad(): 0.04%
# tBodyGyroMag-max(): 0.02%
# tBodyGyroMag-min(): 0.0%
# tBodyGyroMag-sma(): 0.01%
# tBodyGyroMag-energy(): 0.0%
# tBodyGyroMag-iqr(): 0.04%
# tBodyGyroMag-entropy(): 0.0%
# tBodyGyroMag-arCoeff()1: 0.0%
# tBodyGyroMag-arCoeff()2: 0.0%
# tBodyGyroMag-arCoeff()3: 0.0%
# tBodyGyroMag-arCoeff()4: 0.0%
# tBodyGyroJerkMag-mean(): 0.0%
# tBodyGyroJerkMag-std(): 0.0%
# tBodyGyroJerkMag-mad(): 0.03%
# tBodyGyroJerkMag-max(): 0.0%
# tBodyGyroJerkMag-min(): 0.02%
# tBodyGyroJerkMag-sma(): 0.02%
# tBodyGyroJerkMag-energy(): 0.0%
# tBodyGyroJerkMag-iqr(): 0.02%
# tBodyGyroJerkMag-entropy(): 0.0%
# tBodyGyroJerkMag-arCoeff()1: 0.0%
# tBodyGyroJerkMag-arCoeff()2: 0.0%
# tBodyGyroJerkMag-arCoeff()3: 0.0%
# tBodyGyroJerkMag-arCoeff()4: 0.0%
# fBodyAcc-mean()-X: 0.0%
# fBodyAcc-mean()-Y: 0.03%
# fBodyAcc-mean()-Z: 0.03%
# fBodyAcc-std()-X: 0.02%
# fBodyAcc-std()-Y: 0.0%
# fBodyAcc-std()-Z: 0.0%
# fBodyAcc-mad()-X: 0.01%
# fBodyAcc-mad()-Y: 0.03%
# fBodyAcc-mad()-Z: 0.03%
# fBodyAcc-max()-X: 0.03%
# fBodyAcc-max()-Y: 0.01%
# fBodyAcc-max()-Z: 0.0%
# fBodyAcc-min()-X: 0.0%
# fBodyAcc-min()-Y: 0.0%
# fBodyAcc-min()-Z: 0.0%
# fBodyAcc-sma(): 0.02%
# fBodyAcc-energy()-X: 0.0%
# fBodyAcc-energy()-Y: 0.0%
# fBodyAcc-energy()-Z: 0.0%
# fBodyAcc-iqr()-X: 0.0%
# fBodyAcc-iqr()-Y: 0.02%
# fBodyAcc-iqr()-Z: 0.01%
# fBodyAcc-entropy()-X: 0.03%
# fBodyAcc-entropy()-Y: 0.04%
# fBodyAcc-entropy()-Z: 0.0%
# fBodyAcc-maxInds-X: 0.0%
# fBodyAcc-maxInds-Y: 0.0%
# fBodyAcc-maxInds-Z: 0.0%
# fBodyAcc-meanFreq()-X: 0.0%
# fBodyAcc-meanFreq()-Y: 0.0%
# fBodyAcc-meanFreq()-Z: 0.0%
# fBodyAcc-skewness()-X: 0.0%
# fBodyAcc-kurtosis()-X: 0.0%
# fBodyAcc-skewness()-Y: 0.0%
# fBodyAcc-kurtosis()-Y: 0.0%
# fBodyAcc-skewness()-Z: 0.0%
# fBodyAcc-kurtosis()-Z: 0.0%
# fBodyAcc-bandsEnergy()-1,8: 0.0%
# fBodyAcc-bandsEnergy()-9,16: 0.0%
# fBodyAcc-bandsEnergy()-17,24: 0.0%
# fBodyAcc-bandsEnergy()-25,32: 0.0%
# fBodyAcc-bandsEnergy()-33,40: 0.0%
# fBodyAcc-bandsEnergy()-41,48: 0.0%
# fBodyAcc-bandsEnergy()-49,56: 0.0%
# fBodyAcc-bandsEnergy()-57,64: 0.0%
# fBodyAcc-bandsEnergy()-1,16: 0.0%
# fBodyAcc-bandsEnergy()-17,32: 0.0%
# fBodyAcc-bandsEnergy()-33,48: 0.0%
# fBodyAcc-bandsEnergy()-49,64: 0.0%
# fBodyAcc-bandsEnergy()-1,24: 0.0%
# fBodyAcc-bandsEnergy()-25,48: 0.0%
# fBodyAcc-bandsEnergy()-1,8.1: 0.0%
# fBodyAcc-bandsEnergy()-9,16.1: 0.0%
# fBodyAcc-bandsEnergy()-17,24.1: 0.0%
# fBodyAcc-bandsEnergy()-25,32.1: 0.0%
# fBodyAcc-bandsEnergy()-33,40.1: 0.0%
# fBodyAcc-bandsEnergy()-41,48.1: 0.0%
# fBodyAcc-bandsEnergy()-49,56.1: 0.0%
# fBodyAcc-bandsEnergy()-57,64.1: 0.0%
# fBodyAcc-bandsEnergy()-1,16.1: 0.02%
# fBodyAcc-bandsEnergy()-17,32.1: 0.0%
# fBodyAcc-bandsEnergy()-33,48.1: 0.0%
# fBodyAcc-bandsEnergy()-49,64.1: 0.0%
# fBodyAcc-bandsEnergy()-1,24.1: 0.01%
# fBodyAcc-bandsEnergy()-25,48.1: 0.0%
# fBodyAcc-bandsEnergy()-1,8.2: 0.0%
# fBodyAcc-bandsEnergy()-9,16.2: 0.0%
# fBodyAcc-bandsEnergy()-17,24.2: 0.0%
# fBodyAcc-bandsEnergy()-25,32.2: 0.0%
# fBodyAcc-bandsEnergy()-33,40.2: 0.0%
# fBodyAcc-bandsEnergy()-41,48.2: 0.0%
# fBodyAcc-bandsEnergy()-49,56.2: 0.0%
# fBodyAcc-bandsEnergy()-57,64.2: 0.0%
# fBodyAcc-bandsEnergy()-1,16.2: 0.0%
# fBodyAcc-bandsEnergy()-17,32.2: 0.0%
# fBodyAcc-bandsEnergy()-33,48.2: 0.0%
# fBodyAcc-bandsEnergy()-49,64.2: 0.0%
# fBodyAcc-bandsEnergy()-1,24.2: 0.0%
# fBodyAcc-bandsEnergy()-25,48.2: 0.0%
# fBodyAccJerk-mean()-X: 0.03%
# fBodyAccJerk-mean()-Y: 0.04%
# fBodyAccJerk-mean()-Z: 0.0%
# fBodyAccJerk-std()-X: 0.02%
# fBodyAccJerk-std()-Y: 0.05%
# fBodyAccJerk-std()-Z: 0.01%
# fBodyAccJerk-mad()-X: 0.01%
# fBodyAccJerk-mad()-Y: 0.02%
# fBodyAccJerk-mad()-Z: 0.01%
# fBodyAccJerk-max()-X: 0.02%
# fBodyAccJerk-max()-Y: 0.01%
# fBodyAccJerk-max()-Z: 0.03%
# fBodyAccJerk-min()-X: 0.0%
# fBodyAccJerk-min()-Y: 0.0%
# fBodyAccJerk-min()-Z: 0.0%
# fBodyAccJerk-sma(): 0.0%
# fBodyAccJerk-energy()-X: 0.02%
# fBodyAccJerk-energy()-Y: 0.01%
# fBodyAccJerk-energy()-Z: 0.0%
# fBodyAccJerk-iqr()-X: 0.0%
# fBodyAccJerk-iqr()-Y: 0.03%
# fBodyAccJerk-iqr()-Z: 0.02%
# fBodyAccJerk-entropy()-X: 0.03%
# fBodyAccJerk-entropy()-Y: 0.01%
# fBodyAccJerk-entropy()-Z: 0.03%
# fBodyAccJerk-maxInds-X: 0.0%
# fBodyAccJerk-maxInds-Y: 0.0%
# fBodyAccJerk-maxInds-Z: 0.0%
# fBodyAccJerk-meanFreq()-X: 0.0%
# fBodyAccJerk-meanFreq()-Y: 0.0%
# fBodyAccJerk-meanFreq()-Z: 0.0%
# fBodyAccJerk-skewness()-X: 0.0%
# fBodyAccJerk-kurtosis()-X: 0.0%
# fBodyAccJerk-skewness()-Y: 0.0%
# fBodyAccJerk-kurtosis()-Y: 0.0%
# fBodyAccJerk-skewness()-Z: 0.0%
# fBodyAccJerk-kurtosis()-Z: 0.0%
# fBodyAccJerk-bandsEnergy()-1,8: 0.0%
# fBodyAccJerk-bandsEnergy()-9,16: 0.0%
# fBodyAccJerk-bandsEnergy()-17,24: 0.0%
# fBodyAccJerk-bandsEnergy()-25,32: 0.0%
# fBodyAccJerk-bandsEnergy()-33,40: 0.0%
# fBodyAccJerk-bandsEnergy()-41,48: 0.0%
# fBodyAccJerk-bandsEnergy()-49,56: 0.0%
# fBodyAccJerk-bandsEnergy()-57,64: 0.0%
# fBodyAccJerk-bandsEnergy()-1,16: 0.0%
# fBodyAccJerk-bandsEnergy()-17,32: 0.0%
# fBodyAccJerk-bandsEnergy()-33,48: 0.0%
# fBodyAccJerk-bandsEnergy()-49,64: 0.0%
# fBodyAccJerk-bandsEnergy()-1,24: 0.0%
# fBodyAccJerk-bandsEnergy()-25,48: 0.0%
# fBodyAccJerk-bandsEnergy()-1,8.1: 0.0%
# fBodyAccJerk-bandsEnergy()-9,16.1: 0.0%
# fBodyAccJerk-bandsEnergy()-17,24.1: 0.0%
# fBodyAccJerk-bandsEnergy()-25,32.1: 0.0%
# fBodyAccJerk-bandsEnergy()-33,40.1: 0.0%
# fBodyAccJerk-bandsEnergy()-41,48.1: 0.0%
# fBodyAccJerk-bandsEnergy()-49,56.1: 0.0%
# fBodyAccJerk-bandsEnergy()-57,64.1: 0.0%
# fBodyAccJerk-bandsEnergy()-1,16.1: 0.0%
# fBodyAccJerk-bandsEnergy()-17,32.1: 0.0%
# fBodyAccJerk-bandsEnergy()-33,48.1: 0.0%
# fBodyAccJerk-bandsEnergy()-49,64.1: 0.0%
# fBodyAccJerk-bandsEnergy()-1,24.1: 0.01%
# fBodyAccJerk-bandsEnergy()-25,48.1: 0.0%
# fBodyAccJerk-bandsEnergy()-1,8.2: 0.0%
# fBodyAccJerk-bandsEnergy()-9,16.2: 0.0%
# fBodyAccJerk-bandsEnergy()-17,24.2: 0.0%
# fBodyAccJerk-bandsEnergy()-25,32.2: 0.0%
# fBodyAccJerk-bandsEnergy()-33,40.2: 0.0%
# fBodyAccJerk-bandsEnergy()-41,48.2: 0.0%
# fBodyAccJerk-bandsEnergy()-49,56.2: 0.0%
# fBodyAccJerk-bandsEnergy()-57,64.2: 0.0%
# fBodyAccJerk-bandsEnergy()-1,16.2: 0.0%
# fBodyAccJerk-bandsEnergy()-17,32.2: 0.0%
# fBodyAccJerk-bandsEnergy()-33,48.2: 0.0%
# fBodyAccJerk-bandsEnergy()-49,64.2: 0.0%
# fBodyAccJerk-bandsEnergy()-1,24.2: 0.0%
# fBodyAccJerk-bandsEnergy()-25,48.2: 0.0%
# fBodyGyro-mean()-X: 0.0%
# fBodyGyro-mean()-Y: 0.02%
# fBodyGyro-mean()-Z: 0.01%
# fBodyGyro-std()-X: 0.0%
# fBodyGyro-std()-Y: 0.0%
# fBodyGyro-std()-Z: 0.0%
# fBodyGyro-mad()-X: 0.0%
# fBodyGyro-mad()-Y: 0.0%
# fBodyGyro-mad()-Z: 0.01%
# fBodyGyro-max()-X: 0.0%
# fBodyGyro-max()-Y: 0.0%
# fBodyGyro-max()-Z: 0.0%
# fBodyGyro-min()-X: 0.0%
# fBodyGyro-min()-Y: 0.0%
# fBodyGyro-min()-Z: 0.0%
# fBodyGyro-sma(): 0.02%
# fBodyGyro-energy()-X: 0.0%
# fBodyGyro-energy()-Y: 0.0%
# fBodyGyro-energy()-Z: 0.0%
# fBodyGyro-iqr()-X: 0.02%
# fBodyGyro-iqr()-Y: 0.03%
# fBodyGyro-iqr()-Z: 0.01%
# fBodyGyro-entropy()-X: 0.03%
# fBodyGyro-entropy()-Y: 0.0%
# fBodyGyro-entropy()-Z: 0.03%
# fBodyGyro-maxInds-X: 0.0%
# fBodyGyro-maxInds-Y: 0.0%
# fBodyGyro-maxInds-Z: 0.0%
# fBodyGyro-meanFreq()-X: 0.0%
# fBodyGyro-meanFreq()-Y: 0.0%
# fBodyGyro-meanFreq()-Z: 0.0%
# fBodyGyro-skewness()-X: 0.0%
# fBodyGyro-kurtosis()-X: 0.0%
# fBodyGyro-skewness()-Y: 0.0%
# fBodyGyro-kurtosis()-Y: 0.0%
# fBodyGyro-skewness()-Z: 0.0%
# fBodyGyro-kurtosis()-Z: 0.0%
# fBodyGyro-bandsEnergy()-1,8: 0.0%
# fBodyGyro-bandsEnergy()-9,16: 0.0%
# fBodyGyro-bandsEnergy()-17,24: 0.0%
# fBodyGyro-bandsEnergy()-25,32: 0.0%
# fBodyGyro-bandsEnergy()-33,40: 0.0%
# fBodyGyro-bandsEnergy()-41,48: 0.0%
# fBodyGyro-bandsEnergy()-49,56: 0.0%
# fBodyGyro-bandsEnergy()-57,64: 0.0%
# fBodyGyro-bandsEnergy()-1,16: 0.0%
# fBodyGyro-bandsEnergy()-17,32: 0.0%
# fBodyGyro-bandsEnergy()-33,48: 0.0%
# fBodyGyro-bandsEnergy()-49,64: 0.0%
# fBodyGyro-bandsEnergy()-1,24: 0.0%
# fBodyGyro-bandsEnergy()-25,48: 0.0%
# fBodyGyro-bandsEnergy()-1,8.1: 0.0%
# fBodyGyro-bandsEnergy()-9,16.1: 0.0%
# fBodyGyro-bandsEnergy()-17,24.1: 0.0%
# fBodyGyro-bandsEnergy()-25,32.1: 0.0%
# fBodyGyro-bandsEnergy()-33,40.1: 0.0%
# fBodyGyro-bandsEnergy()-41,48.1: 0.0%
# fBodyGyro-bandsEnergy()-49,56.1: 0.0%
# fBodyGyro-bandsEnergy()-57,64.1: 0.0%
# fBodyGyro-bandsEnergy()-1,16.1: 0.0%
# fBodyGyro-bandsEnergy()-17,32.1: 0.0%
# fBodyGyro-bandsEnergy()-33,48.1: 0.0%
# fBodyGyro-bandsEnergy()-49,64.1: 0.0%
# fBodyGyro-bandsEnergy()-1,24.1: 0.0%
# fBodyGyro-bandsEnergy()-25,48.1: 0.0%
# fBodyGyro-bandsEnergy()-1,8.2: 0.0%
# fBodyGyro-bandsEnergy()-9,16.2: 0.0%
# fBodyGyro-bandsEnergy()-17,24.2: 0.0%
# fBodyGyro-bandsEnergy()-25,32.2: 0.0%
# fBodyGyro-bandsEnergy()-33,40.2: 0.0%
# fBodyGyro-bandsEnergy()-41,48.2: 0.0%
# fBodyGyro-bandsEnergy()-49,56.2: 0.0%
# fBodyGyro-bandsEnergy()-57,64.2: 0.0%
# fBodyGyro-bandsEnergy()-1,16.2: 0.0%
# fBodyGyro-bandsEnergy()-17,32.2: 0.0%
# fBodyGyro-bandsEnergy()-33,48.2: 0.0%
# fBodyGyro-bandsEnergy()-49,64.2: 0.0%
# fBodyGyro-bandsEnergy()-1,24.2: 0.0%
# fBodyGyro-bandsEnergy()-25,48.2: 0.0%
# fBodyAccMag-mean(): 0.02%
# fBodyAccMag-std(): 0.04%
# fBodyAccMag-mad(): 0.02%
# fBodyAccMag-max(): 0.0%
# fBodyAccMag-min(): 0.0%
# fBodyAccMag-sma(): 0.02%
# fBodyAccMag-energy(): 0.0%
# fBodyAccMag-iqr(): 0.02%
# fBodyAccMag-entropy(): 0.01%
# fBodyAccMag-maxInds: 0.0%
# fBodyAccMag-meanFreq(): 0.0%
# fBodyAccMag-skewness(): 0.0%
# fBodyAccMag-kurtosis(): 0.0%
# fBodyBodyAccJerkMag-mean(): 0.03%
# fBodyBodyAccJerkMag-std(): 0.01%
# fBodyBodyAccJerkMag-mad(): 0.01%
# fBodyBodyAccJerkMag-max(): 0.0%
# fBodyBodyAccJerkMag-min(): 0.0%
# fBodyBodyAccJerkMag-sma(): 0.02%
# fBodyBodyAccJerkMag-energy(): 0.01%
# fBodyBodyAccJerkMag-iqr(): 0.02%
# fBodyBodyAccJerkMag-entropy(): 0.01%
# fBodyBodyAccJerkMag-maxInds: 0.0%
# fBodyBodyAccJerkMag-meanFreq(): 0.0%
# fBodyBodyAccJerkMag-skewness(): 0.0%
# fBodyBodyAccJerkMag-kurtosis(): 0.0%
# fBodyBodyGyroMag-mean(): 0.0%
# fBodyBodyGyroMag-std(): 0.01%
# fBodyBodyGyroMag-mad(): 0.02%
# fBodyBodyGyroMag-max(): 0.0%
# fBodyBodyGyroMag-min(): 0.0%
# fBodyBodyGyroMag-sma(): 0.01%
# fBodyBodyGyroMag-energy(): 0.0%
# fBodyBodyGyroMag-iqr(): 0.01%
# fBodyBodyGyroMag-entropy(): 0.02%
# fBodyBodyGyroMag-maxInds: 0.0%
# fBodyBodyGyroMag-meanFreq(): 0.0%
# fBodyBodyGyroMag-skewness(): 0.0%
# fBodyBodyGyroMag-kurtosis(): 0.0%
# fBodyBodyGyroJerkMag-mean(): 0.03%
# fBodyBodyGyroJerkMag-std(): 0.0%
# fBodyBodyGyroJerkMag-mad(): 0.0%
# fBodyBodyGyroJerkMag-max(): 0.0%
# fBodyBodyGyroJerkMag-min(): 0.0%
# fBodyBodyGyroJerkMag-sma(): 0.03%
# fBodyBodyGyroJerkMag-energy(): 0.0%
# fBodyBodyGyroJerkMag-iqr(): 0.0%
# fBodyBodyGyroJerkMag-entropy(): 0.03%
# fBodyBodyGyroJerkMag-maxInds: 0.0%
# fBodyBodyGyroJerkMag-meanFreq(): 0.0%
# fBodyBodyGyroJerkMag-skewness(): 0.0%
# fBodyBodyGyroJerkMag-kurtosis(): 0.0%
# angle(tBodyAccMean,gravity): 0.0%
# angle(tBodyAccJerkMean),gravityMean): 0.0%
# angle(tBodyGyroMean,gravityMean): 0.0%
# angle(tBodyGyroJerkMean,gravityMean): 0.0%
# angle(X,gravityMean): 0.0%
# angle(Y,gravityMean): 0.0%
# angle(Z,gravityMean): 0.0%
# Activity: 0.0%
#
# Porcentaje total de valores nulos en el conjunto de datos: 0.0%

# %% [markdown]
# al haber columnas con porcentajes nulos, para hacer más simple el procesado de datos, haré un simple código para recoger cuales son las variables con valores núlos y clasificarlos en numéricos o categóricos, siendo así más sencillo de procesar después

# %%
# Detectar y mostrar columnas con valores nulos
println("Columnas con valores nulos:\n")

for columna in names(datos)
    if any(ismissing.(datos[!, columna]))  # Verifica si hay algún valor nulo en la columna
        println("Columna con valores nulos: ", columna)
    end
end
# Out:
# Columnas con valores nulos:
#
# Columna con valores nulos: tBodyAcc-std()-X
# Columna con valores nulos: tBodyAcc-std()-Z
# Columna con valores nulos: tBodyAcc-mad()-X
# Columna con valores nulos: tBodyAcc-mad()-Y
# Columna con valores nulos: tBodyAcc-mad()-Z
# Columna con valores nulos: tBodyAcc-max()-X
# Columna con valores nulos: tBodyAcc-max()-Z
# Columna con valores nulos: tBodyAcc-sma()
# Columna con valores nulos: tBodyAcc-iqr()-X
# Columna con valores nulos: tBodyAcc-iqr()-Y
# Columna con valores nulos: tBodyAccJerk-std()-X
# Columna con valores nulos: tBodyAccJerk-mad()-X
# Columna con valores nulos: tBodyAccJerk-mad()-Y
# Columna con valores nulos: tBodyAccJerk-mad()-Z
# Columna con valores nulos: tBodyAccJerk-max()-X
# Columna con valores nulos: tBodyAccJerk-sma()
# Columna con valores nulos: tBodyAccJerk-energy()-X
# Columna con valores nulos: tBodyAccJerk-energy()-Y
# Columna con valores nulos: tBodyAccJerk-iqr()-Y
# Columna con valores nulos: tBodyAccJerk-iqr()-Z
# Columna con valores nulos: tBodyAccJerk-entropy()-X
# Columna con valores nulos: tBodyAccJerk-entropy()-Y
# Columna con valores nulos: tBodyAccJerk-entropy()-Z
# Columna con valores nulos: tBodyGyro-mad()-Y
# Columna con valores nulos: tBodyGyro-sma()
# Columna con valores nulos: tBodyGyro-iqr()-Y
# Columna con valores nulos: tBodyGyroJerk-std()-X
# Columna con valores nulos: tBodyGyroJerk-std()-Z
# Columna con valores nulos: tBodyGyroJerk-mad()-X
# Columna con valores nulos: tBodyGyroJerk-mad()-Z
# Columna con valores nulos: tBodyGyroJerk-sma()
# Columna con valores nulos: tBodyGyroJerk-iqr()-X
# Columna con valores nulos: tBodyGyroJerk-iqr()-Z
# Columna con valores nulos: tBodyGyroJerk-entropy()-X
# Columna con valores nulos: tBodyGyroJerk-entropy()-Y
# Columna con valores nulos: tBodyAccMag-std()
# Columna con valores nulos: tBodyAccMag-mad()
# Columna con valores nulos: tBodyAccMag-max()
# Columna con valores nulos: tBodyAccMag-sma()
# Columna con valores nulos: tBodyAccMag-energy()
# Columna con valores nulos: tBodyAccMag-iqr()
# Columna con valores nulos: tBodyAccMag-entropy()
# Columna con valores nulos: tGravityAccMag-mean()
# Columna con valores nulos: tGravityAccMag-std()
# Columna con valores nulos: tGravityAccMag-mad()
# Columna con valores nulos: tGravityAccMag-max()
# Columna con valores nulos: tGravityAccMag-sma()
# Columna con valores nulos: tGravityAccMag-energy()
# Columna con valores nulos: tGravityAccMag-iqr()
# Columna con valores nulos: tGravityAccMag-entropy()
# Columna con valores nulos: tBodyAccJerkMag-mean()
# Columna con valores nulos: tBodyAccJerkMag-mad()
# Columna con valores nulos: tBodyAccJerkMag-max()
# Columna con valores nulos: tBodyAccJerkMag-min()
# Columna con valores nulos: tBodyAccJerkMag-sma()
# Columna con valores nulos: tBodyAccJerkMag-energy()
# Columna con valores nulos: tBodyAccJerkMag-iqr()
# Columna con valores nulos: tBodyAccJerkMag-entropy()
# Columna con valores nulos: tBodyGyroMag-std()
# Columna con valores nulos: tBodyGyroMag-mad()
# Columna con valores nulos: tBodyGyroMag-max()
# Columna con valores nulos: tBodyGyroMag-sma()
# Columna con valores nulos: tBodyGyroMag-iqr()
# Columna con valores nulos: tBodyGyroJerkMag-mad()
# Columna con valores nulos: tBodyGyroJerkMag-min()
# Columna con valores nulos: tBodyGyroJerkMag-sma()
# Columna con valores nulos: tBodyGyroJerkMag-iqr()
# Columna con valores nulos: fBodyAcc-mean()-Y
# Columna con valores nulos: fBodyAcc-mean()-Z
# Columna con valores nulos: fBodyAcc-std()-X
# Columna con valores nulos: fBodyAcc-mad()-X
# Columna con valores nulos: fBodyAcc-mad()-Y
# Columna con valores nulos: fBodyAcc-mad()-Z
# Columna con valores nulos: fBodyAcc-max()-X
# Columna con valores nulos: fBodyAcc-max()-Y
# Columna con valores nulos: fBodyAcc-sma()
# Columna con valores nulos: fBodyAcc-iqr()-Y
# Columna con valores nulos: fBodyAcc-iqr()-Z
# Columna con valores nulos: fBodyAcc-entropy()-X
# Columna con valores nulos: fBodyAcc-entropy()-Y
# Columna con valores nulos: fBodyAcc-bandsEnergy()-1,16.1
# Columna con valores nulos: fBodyAcc-bandsEnergy()-1,24.1
# Columna con valores nulos: fBodyAccJerk-mean()-X
# Columna con valores nulos: fBodyAccJerk-mean()-Y
# Columna con valores nulos: fBodyAccJerk-std()-X
# Columna con valores nulos: fBodyAccJerk-std()-Y
# Columna con valores nulos: fBodyAccJerk-std()-Z
# Columna con valores nulos: fBodyAccJerk-mad()-X
# Columna con valores nulos: fBodyAccJerk-mad()-Y
# Columna con valores nulos: fBodyAccJerk-mad()-Z
# Columna con valores nulos: fBodyAccJerk-max()-X
# Columna con valores nulos: fBodyAccJerk-max()-Y
# Columna con valores nulos: fBodyAccJerk-max()-Z
# Columna con valores nulos: fBodyAccJerk-energy()-X
# Columna con valores nulos: fBodyAccJerk-energy()-Y
# Columna con valores nulos: fBodyAccJerk-iqr()-Y
# Columna con valores nulos: fBodyAccJerk-iqr()-Z
# Columna con valores nulos: fBodyAccJerk-entropy()-X
# Columna con valores nulos: fBodyAccJerk-entropy()-Y
# Columna con valores nulos: fBodyAccJerk-entropy()-Z
# Columna con valores nulos: fBodyAccJerk-bandsEnergy()-1,24.1
# Columna con valores nulos: fBodyGyro-mean()-Y
# Columna con valores nulos: fBodyGyro-mean()-Z
# Columna con valores nulos: fBodyGyro-mad()-Z
# Columna con valores nulos: fBodyGyro-sma()
# Columna con valores nulos: fBodyGyro-iqr()-X
# Columna con valores nulos: fBodyGyro-iqr()-Y
# Columna con valores nulos: fBodyGyro-iqr()-Z
# Columna con valores nulos: fBodyGyro-entropy()-X
# Columna con valores nulos: fBodyGyro-entropy()-Z
# Columna con valores nulos: fBodyAccMag-mean()
# Columna con valores nulos: fBodyAccMag-std()
# Columna con valores nulos: fBodyAccMag-mad()
# Columna con valores nulos: fBodyAccMag-sma()
# Columna con valores nulos: fBodyAccMag-iqr()
# Columna con valores nulos: fBodyAccMag-entropy()
# Columna con valores nulos: fBodyBodyAccJerkMag-mean()
# Columna con valores nulos: fBodyBodyAccJerkMag-std()
# Columna con valores nulos: fBodyBodyAccJerkMag-mad()
# Columna con valores nulos: fBodyBodyAccJerkMag-sma()
# Columna con valores nulos: fBodyBodyAccJerkMag-energy()
# Columna con valores nulos: fBodyBodyAccJerkMag-iqr()
# Columna con valores nulos: fBodyBodyAccJerkMag-entropy()
# Columna con valores nulos: fBodyBodyGyroMag-std()
# Columna con valores nulos: fBodyBodyGyroMag-mad()
# Columna con valores nulos: fBodyBodyGyroMag-sma()
# Columna con valores nulos: fBodyBodyGyroMag-iqr()
# Columna con valores nulos: fBodyBodyGyroMag-entropy()
# Columna con valores nulos: fBodyBodyGyroJerkMag-mean()
# Columna con valores nulos: fBodyBodyGyroJerkMag-sma()
# Columna con valores nulos: fBodyBodyGyroJerkMag-entropy()

# %%
# Detectar y mostrar columnas con valores nulos
println("Columnas con valores nulos y clasificables:\n")

for columna in names(datos)
    if any(ismissing.(datos[!, columna]))  # Verifica si hay algún valor nulo en la columna
        # Verifica si la columna tiene más de 50 valores únicos (son lo suficientemente grandes como para saber si no es categórico)
        if length(unique(datos[!, columna])) < 100
            clases = unique(datos[!, columna])
            println("Número de clases únicas en la columna ", columna, ": ", length(clases))
        end
    end
end
# Out:
# Columnas con valores nulos y clasificables:

# %% [markdown]
# Con esto, sabemos que unicamente hay valores nulos en los valores numéricos. por lo que ahora podemos tratarlos de una mejor forma.

# %%
columnas_valores_nulos = []  # Inicializa un arreglo vacío

for columna in names(datos)
    if any(ismissing.(datos[!, columna]))  # Verifica si hay algún valor nulo en la columna
        push!(columnas_valores_nulos, columna)  # Agrega la columna al arreglo
    end
end

println("Columnas con valores nulos: ", columnas_valores_nulos)


# Ahora tenemos un array con las columnas con valores nulos.
# Out:
# Columnas con valores nulos: Any["tBodyAcc-std()-X", "tBodyAcc-std()-Z", "tBodyAcc-mad()-X", "tBodyAcc-mad()-Y", "tBodyAcc-mad()-Z", "tBodyAcc-max()-X", "tBodyAcc-max()-Z", "tBodyAcc-sma()", "tBodyAcc-iqr()-X", "tBodyAcc-iqr()-Y", "tBodyAccJerk-std()-X", "tBodyAccJerk-mad()-X", "tBodyAccJerk-mad()-Y", "tBodyAccJerk-mad()-Z", "tBodyAccJerk-max()-X", "tBodyAccJerk-sma()", "tBodyAccJerk-energy()-X", "tBodyAccJerk-energy()-Y", "tBodyAccJerk-iqr()-Y", "tBodyAccJerk-iqr()-Z", "tBodyAccJerk-entropy()-X", "tBodyAccJerk-entropy()-Y", "tBodyAccJerk-entropy()-Z", "tBodyGyro-mad()-Y", "tBodyGyro-sma()", "tBodyGyro-iqr()-Y", "tBodyGyroJerk-std()-X", "tBodyGyroJerk-std()-Z", "tBodyGyroJerk-mad()-X", "tBodyGyroJerk-mad()-Z", "tBodyGyroJerk-sma()", "tBodyGyroJerk-iqr()-X", "tBodyGyroJerk-iqr()-Z", "tBodyGyroJerk-entropy()-X", "tBodyGyroJerk-entropy()-Y", "tBodyAccMag-std()", "tBodyAccMag-mad()", "tBodyAccMag-max()", "tBodyAccMag-sma()", "tBodyAccMag-energy()", "tBodyAccMag-iqr()", "tBodyAccMag-entropy()", "tGravityAccMag-mean()", "tGravityAccMag-std()", "tGravityAccMag-mad()", "tGravityAccMag-max()", "tGravityAccMag-sma()", "tGravityAccMag-energy()", "tGravityAccMag-iqr()", "tGravityAccMag-entropy()", "tBodyAccJerkMag-mean()", "tBodyAccJerkMag-mad()", "tBodyAccJerkMag-max()", "tBodyAccJerkMag-min()", "tBodyAccJerkMag-sma()", "tBodyAccJerkMag-energy()", "tBodyAccJerkMag-iqr()", "tBodyAccJerkMag-entropy()", "tBodyGyroMag-std()", "tBodyGyroMag-mad()", "tBodyGyroMag-max()", "tBodyGyroMag-sma()", "tBodyGyroMag-iqr()", "tBodyGyroJerkMag-mad()", "tBodyGyroJerkMag-min()", "tBodyGyroJerkMag-sma()", "tBodyGyroJerkMag-iqr()", "fBodyAcc-mean()-Y", "fBodyAcc-mean()-Z", "fBodyAcc-std()-X", "fBodyAcc-mad()-X", "fBodyAcc-mad()-Y", "fBodyAcc-mad()-Z", "fBodyAcc-max()-X", "fBodyAcc-max()-Y", "fBodyAcc-sma()", "fBodyAcc-iqr()-Y", "fBodyAcc-iqr()-Z", "fBodyAcc-entropy()-X", "fBodyAcc-entropy()-Y", "fBodyAcc-bandsEnergy()-1,16.1", "fBodyAcc-bandsEnergy()-1,24.1", "fBodyAccJerk-mean()-X", "fBodyAccJerk-mean()-Y", "fBodyAccJerk-std()-X", "fBodyAccJerk-std()-Y", "fBodyAccJerk-std()-Z", "fBodyAccJerk-mad()-X", "fBodyAccJerk-mad()-Y", "fBodyAccJerk-mad()-Z", "fBodyAccJerk-max()-X", "fBodyAccJerk-max()-Y", "fBodyAccJerk-max()-Z", "fBodyAccJerk-energy()-X", "fBodyAccJerk-energy()-Y", "fBodyAccJerk-iqr()-Y", "fBodyAccJerk-iqr()-Z", "fBodyAccJerk-entropy()-X", "fBodyAccJerk-entropy()-Y", "fBodyAccJerk-entropy()-Z", "fBodyAccJerk-bandsEnergy()-1,24.1", "fBodyGyro-mean()-Y", "fBodyGyro-mean()-Z", "fBodyGyro-mad()-Z", "fBodyGyro-sma()", "fBodyGyro-iqr()-X", "fBodyGyro-iqr()-Y", "fBodyGyro-iqr()-Z", "fBodyGyro-entropy()-X", "fBodyGyro-entropy()-Z", "fBodyAccMag-mean()", "fBodyAccMag-std()", "fBodyAccMag-mad()", "fBodyAccMag-sma()", "fBodyAccMag-iqr()", "fBodyAccMag-entropy()", "fBodyBodyAccJerkMag-mean()", "fBodyBodyAccJerkMag-std()", "fBodyBodyAccJerkMag-mad()", "fBodyBodyAccJerkMag-sma()", "fBodyBodyAccJerkMag-energy()", "fBodyBodyAccJerkMag-iqr()", "fBodyBodyAccJerkMag-entropy()", "fBodyBodyGyroMag-std()", "fBodyBodyGyroMag-mad()", "fBodyBodyGyroMag-sma()", "fBodyBodyGyroMag-iqr()", "fBodyBodyGyroMag-entropy()", "fBodyBodyGyroJerkMag-mean()", "fBodyBodyGyroJerkMag-sma()", "fBodyBodyGyroJerkMag-entropy()"]

# %% [markdown]
# ### Preparar los datos para técnicas de clasificación
# * Realizar las transformaciones necesarias en los datos.
# * Rellenar los datos faltantes (si existen) utilizando una estrategia apropiada, como:
#   * Media o mediana para variables numéricas.
#   * Modo o una etiqueta específica para valores categóricos.

# %%
for columna in columnas_valores_nulos
    media_columna = mean(skipmissing(datos[!, columna]))  # Calcula la media ignorando nulos
    datos[!, columna] .= coalesce.(datos[!, columna], media_columna)  # Rellena nulos con la media
end

println("Valores nulos en columnas numéricas reemplazados por la media.")
# Out:
# Valores nulos en columnas numéricas reemplazados por la media.

# %%
# Detectar y mostrar columnas con valores nulos
println("Columnas con valores nulos:\n")

for columna in names(datos)
    if any(ismissing.(datos[!, columna]))  # Verifica si hay algún valor nulo en la columna
        println("Columna con valores nulos: ", columna)
    end
end
# Out:
# Columnas con valores nulos:

# %% [markdown]
# ### Realizar un Holdout del 10% de los datos
# * Reservar el 10% de los individuos (no instancias) como conjunto de prueba final.
# * Utilizar la semilla 172 para asegurar la reproducibilidad.
# * Mostrar cuáles son los individuos que quedan fuera del conjunto principal.

# %%
using Random  # Para controlar la semilla

# 1. Obtener los sujetos únicos
sujetos_unicos = unique(datos.subject)

# 2. Seleccionar aleatoriamente el 10% de los sujetos
semilla = 172
Random.seed!(semilla)  # Fijar la semilla para reproducibilidad

n_sujetos_holdout = Int(ceil(0.1 * length(sujetos_unicos)))  # Calcular el 10%
sujetos_holdout = shuffle(sujetos_unicos)[1:n_sujetos_holdout]  # Seleccionar aleatoriamente

println("Sujetos seleccionados para el conjunto de prueba (10%): ", sujetos_holdout)

# 3. Crear conjuntos de entrenamiento y prueba
datos_test = filter(row -> row.subject in sujetos_holdout, datos)  # Filtrar instancias de los sujetos seleccionados
datos_train = filter(row -> !(row.subject in sujetos_holdout), datos)  # El resto va al conjunto de entrenamiento

# 4. Mostrar resultados
println("\nNúmero de instancias en el conjunto de entrenamiento: ", nrow(datos_train))
println("Número de instancias en el conjunto de prueba: ", nrow(datos_test))
# Out:
# Sujetos seleccionados para el conjunto de prueba (10%): [4, 12, 29]
#
# Número de instancias en el conjunto de entrenamiento: 9318
# Número de instancias en el conjunto de prueba: 981

# %%
using Random

# 1. Obtener los sujetos únicos y dividirlos en 5 folds manualmente
sujetos_restantes = unique(datos_train.subject)  # Sujetos de los datos de entrenamiento
n_folds = 5

sujetos_mezclados = shuffle(sujetos_restantes)  # Mezclar sujetos

# Dividir los sujetos en 5 folds
folds = collect(Iterators.partition(sujetos_mezclados, ceil(Int, length(sujetos_mezclados) / n_folds)))


# 2. Función para normalizar los datos usando MinMaxScaler
function minmax_scaler(df::DataFrame)
    df_normalizado = copy(df)
    for col in names(df)
        if eltype(df[!, col]) <: Number  # Normalizar solo columnas numéricas
            min_val = minimum(skipmissing(df[!, col]))
            max_val = maximum(skipmissing(df[!, col]))
            df_normalizado[!, col] .= (df[!, col] .- min_val) ./ (max_val - min_val)
        end
    end
    return df_normalizado
end

# 3. Crear los 5 folds y aplicar MinMaxScaler
folds_data = []

for i in 1:n_folds
    # Sujetos en el fold actual
    sujetos_validacion = folds[i]
    
    # Crear conjuntos de validación y entrenamiento
    datos_validacion = filter(row -> row.subject in sujetos_validacion, datos_train)
    datos_entrenamiento = filter(row -> !(row.subject in sujetos_validacion), datos_train)
    
    # Normalizar ambos conjuntos
    datos_entrenamiento_norm = minmax_scaler(datos_entrenamiento)
    datos_validacion_norm = minmax_scaler(datos_validacion)
    
    # Almacenar los datos normalizados
    push!(folds_data, (train=datos_entrenamiento_norm, valid=datos_validacion_norm))
    
    println("Fold $i: Entrenamiento = ", nrow(datos_entrenamiento_norm), 
            " filas, Validación = ", nrow(datos_validacion_norm), " filas")
end

println("\nValidación cruzada 5-Fold completada y normalización aplicada.")
# Out:
# Fold 1: Entrenamiento = 7302 filas, Validación = 2016 filas
# Fold 2: Entrenamiento = 7126 filas, Validación = 2192 filas
# Fold 3: Entrenamiento = 7347 filas, Validación = 1971 filas
# Fold 4: Entrenamiento = 7336 filas, Validación = 1982 filas
# Fold 5: Entrenamiento = 8161 filas, Validación = 1157 filas
#
# Validación cruzada 5-Fold completada y normalización aplicada.

# %% [markdown]
# # Segunda Parte de la Práctica:
# ## Creación de los Modelos Básicos:
#
# ### A continuación, realice las siguientes reducciones de dimensionalidad
# * NO aplicar ningún tipo de reducción
# * Filtrado ANOVA
# * Filtrado Mutual Information
# * Filtrado RFE con el método de LogisticRegression con una eliminación del  50% de las variables en cada pasada.

# %%
using CategoricalArrays

# Función para calcular ANOVA
function anova_f_score(X::DataFrame, y::CategoricalVector)
    scores = Float64[]  # Almacena los puntajes F
    y_vector = convert(Vector{String}, y)  # Convertir CategoricalVector a Vector{String}
    
    for columna in names(X)
        # Calcular varianza entre clases y dentro de clases
        clases = unique(y_vector)
        total_var = var(skipmissing(X[!, columna]))
        entre_clases_var = sum([
            (mean(X[y_vector .== clase, columna]) - mean(X[!, columna]))^2 * sum(y_vector .== clase)
            for clase in clases
        ]) / length(y_vector)
        
        dentro_clases_var = sum([
            var(skipmissing(X[y_vector .== clase, columna])) * sum(y_vector .== clase)
            for clase in clases
        ]) / length(y_vector)
        
        # Calcular el puntaje F
        F = entre_clases_var / dentro_clases_var
        push!(scores, F)
    end
    return scores
end
# Out:
# anova_f_score (generic function with 1 method)

# %%
using LinearAlgebra  # Para log2 seguro

# Función para calcular las probabilidades
function calcular_probabilidades(x::Vector, y::Vector)
    joint_counts = Dict()  # Frecuencia conjunta
    x_counts = Dict()      # Frecuencia marginal de x
    y_counts = Dict()      # Frecuencia marginal de y
    
    # Contar frecuencias conjuntas y marginales
    for (xi, yi) in zip(x, y)
        joint_counts[(xi, yi)] = get(joint_counts, (xi, yi), 0) + 1
        x_counts[xi] = get(x_counts, xi, 0) + 1
        y_counts[yi] = get(y_counts, yi, 0) + 1
    end
    
    n = length(x)  # Número total de observaciones
    joint_prob = Dict(k => v / n for (k, v) in joint_counts)
    x_prob = Dict(k => v / n for (k, v) in x_counts)
    y_prob = Dict(k => v / n for (k, v) in y_counts)
    
    return joint_prob, x_prob, y_prob
end

# Función para calcular Mutual Information
function mutual_information(x::Vector, y::Vector)
    joint_prob, x_prob, y_prob = calcular_probabilidades(x, y)
    mi = 0.0
    
    for ((xi, yi), p_xy) in joint_prob
        p_x = x_prob[xi]
        p_y = y_prob[yi]
        mi += p_xy * log2(p_xy / (p_x * p_y))
    end
    
    return mi
end

# Función para calcular MI para todas las características
function mutual_information_scores(X::DataFrame, y::CategoricalVector)
    scores = Float64[]
    y_vector = convert(Vector{String}, y)  # Convertir a Vector{String}
    
    for columna in names(X)
        feature_vector = X[!, columna]
        mi = mutual_information(feature_vector, y_vector)
        push!(scores, mi)
    end
    
    return scores
end
# Out:
# mutual_information_scores (generic function with 1 method)

# %%
using MLJBase
using MLJLinearModels
using DataFrames
using Statistics

function rfe(X::DataFrame, y::CategoricalVector; modelo=:logistic, k::Int=10, eliminar::Float64=0.5)
    remaining_features = names(X)  # Inicialmente todas las características
    y_vector = coerce(y, Multiclass)

    while length(remaining_features) > k
        println("Número de características restantes: ", length(remaining_features))

        # Seleccionar solo las características restantes
        X_subset = DataFrames.select(X, remaining_features)

        # Entrenar el modelo base
        if modelo == :logistic
            model = LogisticClassifier()
            mach = machine(model, X_subset, y_vector) |> fit!
        else
            error("Modelo no soportado")
        end

        # Obtener la importancia de las características
        params = fitted_params(mach)
        coefs = params.coefs  # Esto es una matriz (#clases - 1, #features)
        # Si es binario (2 clases), coefs es de tamaño (1, #features)
        # Si es multiclase, por ejemplo 6 clases, coefs es de tamaño (5, #features)

        if size(coefs, 1) == 1
            # Caso binario
            feature_coefs = coefs[1, :]
        else
            # Caso multiclase, por ejemplo promediamos la importancia
            feature_coefs = vec(mean(abs.(coefs), dims=1))
        end

        feature_importance = zip(remaining_features, abs.(feature_coefs))
        sorted_features = sort(collect(feature_importance), by=x -> x[2], rev=true)

        # Eliminar el 50% menos importante
        threshold = ceil(Int, length(remaining_features) * eliminar)
        remaining_features = [f[1] for f in sorted_features[1:end-threshold]]
    end

    println("Características seleccionadas por RFE: ", remaining_features)
    return DataFrames.select(X, remaining_features)
end
# Out:
# rfe (generic function with 1 method)

# %%
# Función preparar_datos
function preparar_datos(df::DataFrame; columna_objetivo::Symbol=:Activity, reduccion::String="none", k::Int=10)
    # Separar características y etiquetas
    X = DataFrames.select(df, Not(columna_objetivo))

    y = categorical(df[!, columna_objetivo])  # Convertir a CategoricalVector

    # Aplicar reducción de dimensionalidad (opcional)
    if reduccion == "none"
        println("No se aplicó reducción de dimensionalidad.")
    elseif reduccion == "ANOVA"
        println("Aplicando reducción de dimensionalidad con ANOVA.")
        scores = anova_f_score(X, y)
        top_k_indices = sortperm(scores, rev=true)[1:k]
        X = DataFrames.select(X, names(X)[top_k_indices])
        println("Características seleccionadas con ANOVA: ", names(X))
    elseif reduccion == "MI"
        println("Aplicando reducción de dimensionalidad con Mutual Information.")
        scores = mutual_information_scores(X, y)
        top_k_indices = sortperm(scores, rev=true)[1:k]
        X = DataFrames.select(X, names(X)[top_k_indices])
        println("Características seleccionadas con Mutual Information: ", names(X))
    elseif reduccion == "RFE"
        println("Aplicando reducción de dimensionalidad con RFE.")
        X = rfe(X, y; k=k)
    else
        println("Método de reducción no reconocido: ", reduccion)
    end

    return X, y
end


X, y = preparar_datos(datos_train, reduccion="none")
X_ANOVA, y = preparar_datos(datos_train, reduccion="ANOVA", k=15)
X_MI, y = preparar_datos(datos_train, reduccion="MI", k=10)
X_RFE, y = preparar_datos(datos_train, reduccion="RFE", k=10)
# Out:
# No se aplicó reducción de dimensionalidad.
# Aplicando reducción de dimensionalidad con ANOVA.
# Características seleccionadas con ANOVA: ["fBodyAccJerk-entropy()-X", "tGravityAcc-mean()-X", "tGravityAcc-min()-X", "tGravityAcc-max()-X", "tGravityAcc-energy()-X", "fBodyAccJerk-entropy()-Y", "tBodyAccJerkMag-entropy()", "fBodyBodyAccJerkMag-entropy()", "fBodyAcc-entropy()-X", "tBodyAccJerk-entropy()-X", "tBodyAcc-max()-X", "fBodyAccJerk-entropy()-Z", "tBodyAccJerk-entropy()-Z", "angle(X,gravityMean)", "tBodyAccJerk-entropy()-Y"]
# Aplicando reducción de dimensionalidad con Mutual Information.
# Características seleccionadas con Mutual Information: ["fBodyGyro-skewness()-Z", "tGravityAcc-arCoeff()-X,1", "tBodyGyroJerk-arCoeff()-X,3", "tBodyGyro-correlation()-X,Z", "tBodyAccJerk-arCoeff()-Z,4", "tBodyGyro-correlation()-Y,Z", "tBodyAccJerk-mean()-X", "fBodyAcc-skewness()-Z", "fBodyBodyGyroMag-skewness()", "tBodyAccMag-arCoeff()4"]
# Aplicando reducción de dimensionalidad con RFE.
# Número de características restantes: 562
# ┌ Warning: The number and/or types of data arguments do not match what the specified model
# │ supports. Suppress this type check by specifying `scitype_check_level=0`.
# │
# │ Run `@doc MLJLinearModels.LogisticClassifier` to learn more about your model's requirements.
# │
# │ Commonly, but non exclusively, supervised models are constructed using the syntax
# │ `machine(model, X, y)` or `machine(model, X, y, w)` while most other models are
# │ constructed with `machine(model, X)`.  Here `X` are features, `y` a target, and `w`
# │ sample or class weights.
# │
# │ In general, data in `machine(model, data...)` is expected to satisfy
# │
# │     scitype(data) <: MLJ.fit_data_scitype(model)
# │
# │ In the present case:
# │
# │ scitype(data) = Tuple{Table{Union{AbstractVector{Continuous}, AbstractVector{Count}}}, AbstractVector{Multiclass{6}}}
# │
# │ fit_data_scitype(model) = Tuple{Table{<:AbstractVector{<:Continuous}}, AbstractVector{<:Finite}}
# └ @ MLJBase C:\Users\igran\.julia\packages\MLJBase\7nGJF\src\machines.jl:237
# ┌ Info: Training machine(LogisticClassifier(lambda = 2.220446049250313e-16, …), …).
# └ @ MLJBase C:\Users\igran\.julia\packages\MLJBase\7nGJF\src\machines.jl:499
# ┌ Info: Solver: LBFGS{Optim.Options{Float64, Nothing}, @NamedTuple{}}
# │   optim_options: Optim.Options{Float64, Nothing}
# │   lbfgs_options: @NamedTuple{} NamedTuple()
# └ @ MLJLinearModels C:\Users\igran\.julia\packages\MLJLinearModels\yYgtO\src\mlj\interface.jl:72
# MethodError: no method matching abs(::Pair{Symbol, SubArray{Float64, 1, Matrix{Float64}, Tuple{Int64, Base.Slice{Base.OneTo{Int64}}}, true}})
#
# The function `abs` exists, but no method is defined for this combination of argument types.
#
#
#
# Closest candidates are:
#
#   abs(!Matched::Bool)
#
#    @ Base bool.jl:153
#
#   abs(!Matched::Pkg.Resolve.FieldValue)
#
#    @ Pkg C:\Users\igran\.julia\juliaup\julia-1.11.1+0.x64.w64.mingw32\share\julia\stdlib\v1.11\Pkg\src\Resolve\fieldvalues.jl:51
#
#   abs(!Matched::Missing)
#
#    @ Base missing.jl:101
#
#   ...
#
#
#
#
#
# Stacktrace:
#
#  [1] _broadcast_getindex_evalf
#
#    @ .\broadcast.jl:673 [inlined]
#
#  [2] _broadcast_getindex
#
#    @ .\broadcast.jl:646 [inlined]
#
#  [3] getindex
#
#    @ .\broadcast.jl:605 [inlined]
#
#  [4] copy
#
#    @ .\broadcast.jl:906 [inlined]
#
#  [5] materialize(bc::Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1}, Nothing, typeof(abs), Tuple{Vector{Pair{Symbol, SubArray{Float64, 1, Matrix{Float64}, Tuple{Int64, Base.Slice{Base.OneTo{Int64}}}, true}}}}})
#
#    @ Base.Broadcast .\broadcast.jl:867
#
#  [6] rfe(X::DataFrame, y::CategoricalVector{String31, UInt32, String31, CategoricalValue{String31, UInt32}, Union{}}; modelo::Symbol, k::Int64, eliminar::Float64)
#
#    @ Main d:\Universidad\Tercer_anho\MAAAI\MAAA_I_special_proyect\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X25sZmlsZQ==.jl:35
#
#  [7] preparar_datos(df::DataFrame; columna_objetivo::Symbol, reduccion::String, k::Int64)
#
#    @ Main d:\Universidad\Tercer_anho\MAAAI\MAAA_I_special_proyect\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X26sZmlsZQ==.jl:25
#
#  [8] top-level scope
#
#    @ d:\Universidad\Tercer_anho\MAAAI\MAAA_I_special_proyect\jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X26sZmlsZQ==.jl:37
